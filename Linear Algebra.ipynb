# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.74)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore") 
import yfinance as yf
yf.pdr_override()

# %%
symbol = 'AMD'
start = '2021-08-20'
end = '2022-08-20'
dataset = yf.download(symbol,start,end)
dataset.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High        Low       Close   Adj Close  \
# Date
# 2022-08-15  100.510002  101.849998  99.800003  101.010002  101.010002
# 2022-08-16  100.839996  101.449997  98.320000  100.199997  100.199997
# 2022-08-17   99.260002   99.639999  96.730003   98.269997   98.269997
# 2022-08-18   97.739998  101.070000  96.730003  100.440002  100.440002
# 2022-08-19   98.669998   99.250000  94.589996   95.949997   95.949997
#
#               Volume
# Date
# 2022-08-15  61327100
# 2022-08-16  60220700
# 2022-08-17  63735600
# 2022-08-18  76059500
# 2022-08-19  67167500

# %%
dataset['Returns'] = dataset['Adj Close'].pct_change() 
dataset['Returns'] = dataset['Adj Close'].dropna()

# %%
Returns = np.array(dataset['Returns'])
Open = np.array(dataset['Open'])
Close = np.array(dataset['Adj Close'])
High = np.array(dataset['High'])
Low = np.array(dataset['Low'])

# %%
Close = np.round(Close, 2)
Close
# Out:
# array([104.65, 108.77, 107.65, 108.3 , 107.27, 111.4 , 111.32, 110.72,
#        109.99, 109.2 , 109.92, 109.15, 106.17, 106.15, 105.2 , 104.8 ,
#        105.73, 105.6 , 106.22, 103.88, 101.55, 102.82, 104.38, 106.15,
#        105.8 , 108.16, 101.52, 100.35, 102.9 , 102.45, 100.34, 101.81,
#        103.64, 106.45, 105.06, 104.68, 105.04, 109.16, 111.99, 112.12,
#        116.43, 116.33, 116.39, 119.33, 119.82, 122.36, 122.93, 122.28,
#        121.16, 120.23, 125.23, 127.63, 130.53, 137.5 , 136.34, 150.16,
#        148.92, 139.87, 146.01, 147.89, 146.49, 152.45, 151.34, 155.02,
#        155.41, 152.52, 149.92, 157.8 , 154.81, 161.91, 158.37, 149.11,
#        150.68, 144.01, 139.06, 144.85, 145.24, 138.1 , 138.55, 133.8 ,
#        135.6 , 146.5 , 138.64, 137.75, 135.8 , 144.25, 143.88, 146.14,
#        154.36, 153.15, 148.26, 145.15, 143.9 , 150.24, 144.42, 136.15,
#        136.23, 132.  , 132.  , 137.31, 137.47, 132.74, 136.88, 131.93,
#        128.27, 121.89, 118.81, 116.53, 111.13, 110.71, 102.6 , 105.24,
#        114.25, 116.78, 122.76, 120.08, 123.6 , 123.67, 128.23, 132.85,
#        125.77, 113.18, 114.27, 121.47, 117.69, 112.37, 113.83, 115.65,
#        109.76, 116.61, 121.06, 123.34, 113.83, 118.28, 111.98, 108.41,
#        102.95, 105.53, 111.05, 106.46, 104.29, 102.25, 109.33, 115.37,
#        111.69, 113.46, 115.92, 114.78, 113.92, 120.53, 119.67, 120.24,
#        123.23, 119.22, 109.34, 108.19, 110.53, 106.82, 103.67, 103.72,
#        101.  ,  97.37,  95.1 ,  97.74,  93.06,  93.89,  96.93,  94.02,
#         89.85,  88.14,  90.69,  85.16,  84.91,  89.64,  85.52,  89.84,
#         91.13,  99.42,  93.87,  95.34,  86.36,  88.73,  87.92,  87.06,
#         95.12,  94.24, 102.47,  96.28,  96.67,  93.5 ,  95.07,  91.16,
#         92.65,  98.75, 102.26, 101.86, 101.22, 108.59, 106.3 , 105.65,
#        105.28, 101.9 ,  98.8 ,  94.82,  86.99,  86.99,  89.3 ,  82.05,
#         81.57,  83.79,  83.75,  82.43,  87.08,  86.16,  80.78,  77.99,
#         76.47,  73.67,  75.2 ,  75.35,  79.3 ,  79.35,  76.95,  76.36,
#         77.52,  78.6 ,  81.11,  81.43,  85.88,  89.43,  91.09,  88.1 ,
#         87.54,  85.25,  89.82,  91.67,  94.47,  96.78,  99.29,  98.09,
#        103.91, 102.31, 100.07,  95.54,  99.05,  98.12, 100.83, 101.01,
#        100.2 ,  98.27, 100.44,  95.95])

# %%
import collections
print([item for item, count in collections.Counter(Close).items() if count > 1])
# Out:
# [106.15, 132.0, 113.83, 86.99]

# %% [markdown]
# **Vectors (Rank 1 Tensors) in NumPy**

# %%
x = [item for item, count in collections.Counter(Close).items() if count > 1]
x
# Out:
# [106.15, 132.0, 113.83, 86.99]

# %%
x = np.array(x)
x
# Out:
# array([106.15, 132.  , 113.83,  86.99])

# %%
 len(x)
# Out:
# 4

# %%
x.shape
# Out:
# (4,)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0]
# Out:
# 106.15

# %%
type(x[0])
# Out:
# numpy.float64

# %% [markdown]
# **Vector Transposition**

# %%
x_t = x.T
x_t
# Out:
# array([106.15, 132.  , 113.83,  86.99])

# %%
x_t.shape
# Out:
# (4,)

# %%
Open = np.round(Open, 2)
Open
# Out:
# array([104.32, 105.3 , 109.45, 108.13, 108.57, 108.01, 112.61, 111.26,
#        111.3 , 110.32, 108.85, 109.96, 108.88, 106.56, 106.99, 105.26,
#        105.52, 106.  , 104.92, 105.56, 101.58, 102.15, 102.82, 104.89,
#        105.19, 105.07, 106.84, 102.3 , 102.08, 102.6 , 101.74, 100.92,
#        100.45, 104.6 , 106.55, 104.62, 105.17, 106.28, 110.5 , 112.51,
#        111.9 , 116.16, 116.29, 116.5 , 120.83, 120.52, 122.99, 121.63,
#        122.86, 120.95, 119.45, 124.98, 127.75, 132.01, 139.19, 137.7 ,
#        154.01, 143.93, 142.96, 146.03, 148.  , 145.93, 151.98, 157.07,
#        155.76, 157.14, 150.41, 149.46, 155.8 , 157.5 , 163.28, 160.37,
#        147.68, 151.65, 141.14, 143.9 , 144.96, 145.16, 141.29, 138.25,
#        131.67, 135.11, 147.  , 136.3 , 135.97, 138.19, 142.65, 143.89,
#        147.51, 155.88, 152.82, 147.44, 146.16, 145.14, 151.01, 142.82,
#        136.19, 136.28, 129.08, 133.45, 138.59, 139.44, 131.68, 134.5 ,
#        133.55, 126.04, 120.14, 115.4 , 114.1 , 114.55, 111.96, 101.55,
#        107.93, 116.75, 129.89, 120.32, 120.34, 123.56, 122.38, 129.6 ,
#        128.84, 126.14, 115.51, 117.19, 119.05, 116.26, 113.9 , 115.27,
#        117.4 , 104.56, 117.16, 120.31, 122.33, 115.47, 118.13, 112.  ,
#        108.53, 102.81, 108.41, 108.89, 108.13, 102.99, 102.66, 111.6 ,
#        112.14, 111.28, 113.73, 115.43, 114.29, 114.96, 119.92, 117.7 ,
#        122.28, 123.04, 116.31, 110.48, 109.97, 109.69, 104.45, 103.92,
#        102.51,  98.6 ,  98.78,  95.3 ,  98.37,  92.03,  93.39,  97.84,
#         95.16,  90.03,  89.86,  89.74,  84.25,  86.67,  88.05,  85.66,
#         89.85,  98.18,  97.65,  94.34,  92.87,  89.18,  87.84,  86.6 ,
#         88.3 ,  93.86,  97.88, 100.  ,  96.69,  98.39,  91.66,  92.54,
#         90.43,  91.34, 100.14, 102.43, 102.13, 100.78, 105.8 , 108.27,
#        104.24, 104.57, 101.57,  98.82,  91.26,  87.41,  87.9 ,  86.63,
#         82.19,  84.17,  84.4 ,  84.32,  83.56,  87.36,  85.71,  79.55,
#         77.73,  75.19,  71.98,  75.17,  77.19,  78.31,  77.85,  76.98,
#         74.94,  78.23,  79.36,  82.21,  82.76,  85.39,  89.6 ,  90.2 ,
#         86.57,  87.  ,  86.94,  90.42,  90.7 ,  95.59,  95.71,  94.83,
#         97.5 , 101.05, 100.06,  97.95,  98.45,  99.93,  99.2 , 100.51,
#        100.84,  99.26,  97.74,  98.67])

# %%
y = [item for item, count in collections.Counter(Open).items() if count > 1]
y
# Out:
# [108.13]

# %%
y = np.array([y])

# %%
y.shape
# Out:
# (1, 1)

# %%
y_t = y.T
y_t
# Out:
# array([[108.13]])

# %%
y_t.shape
# Out:
# (1, 1)

# %%
y_t.T
# Out:
# array([[108.13]])

# %%
y_t.T.shape
# Out:
# (1, 1)

# %% [markdown]
# **Torch and Tensorflow**

# %%
import torch
import tensorflow as tf

# %%
x_pt = torch.tensor(x)
x_pt
# Out:
# tensor([106.1500, 132.0000, 113.8300,  86.9900], dtype=torch.float64)

# %%
x_tf = tf.Variable(x)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(4,) dtype=float64, numpy=array([106.15, 132.  , 113.83,  86.99])>

# %% [markdown]
# **L Square Norm**

# %%
x
# Out:
# array([106.15, 132.  , 113.83,  86.99])

# %%
np.linalg.norm(x)
# Out:
# 221.84758619376504

# %%
np.dot(x,x)
# Out:
# 49216.351500000004

# %% [markdown]
# **Max Norm**

# %%
np.max([np.abs(x)])
# Out:
# 132.0

# %% [markdown]
# **Orthogonal Vectors**

# %%
i = np.array([x])
i = i.T
i.shape
# Out:
# (4, 1)

# %%
j = np.array(y)
j.shape
# Out:
# (1, 1)

# %%
np.dot(i, j)
# Out:
# array([[11477.9995],
#        [14273.16  ],
#        [12308.4379],
#        [ 9406.2287]])

# %% [markdown]
# **Convert Array to 2-D Matrix**

# %%
x
# Out:
# array([106.15, 132.  , 113.83,  86.99])

# %%
x.shape
# Out:
# (4,)

# %%
arr_2d = np.reshape(x, (-1, 1))

# %%
print('1D Numpy array:')
print(x)
print("\n")
print('2D Numpy array:')
print(arr_2d)
# Out:
# 1D Numpy array:
# [106.15 132.   113.83  86.99]
#
#
# 2D Numpy array:
# [[106.15]
#  [132.  ]
#  [113.83]
#  [ 86.99]]

# %%
arr_2d.shape
# Out:
# (4, 1)

# %%
arr_2d.size
# Out:
# 4

# %%
arr_2d[:,0]
# Out:
# array([106.15, 132.  , 113.83,  86.99])

# %%
arr_2d[1,:]
# Out:
# array([132.])

# %%
arr_2d[0:2, 0:2]
# Out:
# array([[106.15],
#        [132.  ]])

# %% [markdown]
# **Matrices in PyTorch**

# %%
X_pt = torch.tensor(arr_2d)
X_pt
# Out:
# tensor([[106.1500],
#         [132.0000],
#         [113.8300],
#         [ 86.9900]], dtype=torch.float64)

# %%
X_pt.shape
# Out:
# torch.Size([4, 1])

# %%
X_pt[1,:]
# Out:
# tensor([132.], dtype=torch.float64)

# %% [markdown]
# **Matrices in TensorFlow**

# %%
X_tf = tf.Variable(arr_2d)
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(4, 1) dtype=float64, numpy=
# array([[106.15],
#        [132.  ],
#        [113.83],
#        [ 86.99]])>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([4, 1], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(1,), dtype=float64, numpy=array([132.])>

# %% [markdown]
# **Matrix Transposition**

# %%
X = arr_2d
X
# Out:
# array([[106.15],
#        [132.  ],
#        [113.83],
#        [ 86.99]])

# %%
X.T
# Out:
# array([[106.15, 132.  , 113.83,  86.99]])

# %%
X_pt.T
# Out:
# tensor([[106.1500, 132.0000, 113.8300,  86.9900]], dtype=torch.float64)

# %% [markdown]
# **Matrix Multiplication**

# %%
X*3
# Out:
# array([[318.45],
#        [396.  ],
#        [341.49],
#        [260.97]])

# %%
X*3+3
# Out:
# array([[321.45],
#        [399.  ],
#        [344.49],
#        [263.97]])

# %%
X_pt*3+3
# Out:
# tensor([[321.4500],
#         [399.0000],
#         [344.4900],
#         [263.9700]], dtype=torch.float64)

# %% [markdown]
# **Hadamard product**

# %%
A = np.reshape(y, (-1, 1))
A
# Out:
# array([[108.13]])

# %%
X
# Out:
# array([[106.15],
#        [132.  ],
#        [113.83],
#        [ 86.99]])

# %%
X * A
# Out:
# array([[11477.9995],
#        [14273.16  ],
#        [12308.4379],
#        [ 9406.2287]])

# %%
A_p = torch.tensor(A)
A_p
# Out:
# tensor([[108.1300]], dtype=torch.float64)

# %%
X_pt * A_p
# Out:
# tensor([[11477.9995],
#         [14273.1600],
#         [12308.4379],
#         [ 9406.2287]], dtype=torch.float64)

# %%
X = X.T
np.dot(A, X)
# Out:
# array([[11477.9995, 14273.16  , 12308.4379,  9406.2287]])

# %%
b_p = torch.tensor(X)
b_p
# Out:
# tensor([[106.1500, 132.0000, 113.8300,  86.9900]], dtype=torch.float64)

# %%
torch.matmul(A_p, b_p)
# Out:
# tensor([[11477.9995, 14273.1600, 12308.4379,  9406.2287]], dtype=torch.float64)

# %% [markdown]
# **Matrix Inversion**

# %%
arr_2d
# Out:
# array([[106.15],
#        [132.  ],
#        [113.83],
#        [ 86.99]])

# %%
X = np.array([[2, 8], [-5, -6]])
X
# Out:
# array([[ 2,  8],
#        [-5, -6]])

# %%
Xinv = np.linalg.inv(X)
Xinv
# Out:
# array([[-0.21428571, -0.28571429],
#        [ 0.17857143,  0.07142857]])

# %%
y = np.array([3, -5])
y
# Out:
# array([ 3, -5])

# %%
w = np.dot(Xinv, y)
w
# Out:
# array([0.78571429, 0.17857143])

# %%
np.dot(X, w)
# Out:
# array([ 3., -5.])

# %%
X_p = torch.tensor([[5, 10], [-6, -8.]]) 
X_p
# Out:
# tensor([[ 5., 10.],
#         [-6., -8.]])

# %%
Xinv_p = torch.inverse(X_p)
Xinv_p
# Out:
# tensor([[-0.4000, -0.5000],
#         [ 0.3000,  0.2500]])

# %%
y_p = torch.tensor([4, -7.])
y_p
# Out:
# tensor([ 4., -7.])

# %%
w_p = torch.matmul(Xinv_p, y_p)
w_p
# Out:
# tensor([ 1.9000, -0.5500])

# %%
torch.matmul(X_p, w_p)
# Out:
# tensor([ 4.0000, -7.0000])
